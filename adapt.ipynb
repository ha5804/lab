# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 15,
    "Category": [
        "carpet", "bottle", "hazelnut", "leather", "cable",
        "capsule", "grid", "pill", "transistor", "metal_nut",
        "screw", "toothbrush", "zipper", "tile", "wood"
    ],
    "I_AUROC": [
        100.0, 90.7, 94.8, 100.0, 83.6,
        95.2, 98.9, 86.8, 88.7, 93.7,
        85.9, 86.4, 99.3, 99.6, 98.7
    ],
    "I_AUPR": [
        99.9, 97.1, 97.0, 99.9, 89.9,
        99.0, 99.5, 97.0, 87.1, 98.3,
        93.8, 92.5, 99.8, 99.7, 99.5
    ],
    "I_F1max": [
        100.0, 90.8, 92.4, 99.5, 82.5,
        95.0, 97.3, 93.9, 81.1, 94.7,
        90.3, 95.1, 98.3, 98.2, 96.7
    ],
    "P_AUROC": [
        99.2, 92.4, 97.6, 99.1, 76.6,
        95.8, 97.4, 89.9, 69.3, 76.5,
        97.9, 87.7, 91.8, 95.8, 96.9
    ],
    "P_AUPR": [
        68.2, 60.3, 51.0, 27.9, 15.6,
        35.4, 27.5, 33.1, 15.6, 27.6,
        28.8, 13.5, 44.4, 68.2, 57.5
    ],
    "P_F1max": [
        67.2, 56.4, 53.7, 43.7, 24.7,
        40.2, 39.7, 35.2, 19.5, 34.5,
        34.5, 22.9, 47.7, 67.8, 60.9
    ]
}

df = pd.DataFrame(data)

# 저장
df.to_csv("adaptclip_mvtec_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_mvtec_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_mvtec_0shot.csv

# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 12,
    "Category": [
        "candle", "capsules", "cashew", "chewinggum",
        "fryum", "macaroni1", "macaroni2",
        "pcb1", "pcb2", "pcb3", "pcb4", "pipe_fryum"
    ],
    "I_AUROC": [
        87.4, 93.9, 86.1, 96.7,
        91.5, 83.3, 69.9,
        84.1, 64.6, 65.3, 97.7, 96.7
    ],
    "I_AUPR": [
        90.5, 96.8, 94.0, 98.7,
        95.9, 85.1, 69.2,
        86.1, 67.8, 72.0, 97.5, 98.0
    ],
    "I_F1max": [
        81.4, 91.6, 84.0, 96.4,
        88.5, 75.6, 71.5,
        80.4, 69.9, 67.3, 93.5, 95.6
    ],
    "P_AUROC": [
        98.7, 94.2, 93.4, 99.5,
        95.3, 98.1, 98.2,
        96.2, 93.0, 87.9, 95.3, 98.4
    ],
    "P_AUPR": [
        21.6, 33.4, 22.1, 82.7,
        26.5, 16.4, 2.2,
        15.7, 12.4, 4.6, 31.9, 44.0
    ],
    "P_F1max": [
        35.2, 44.1, 27.2, 77.8,
        33.6, 23.0, 6.4,
        24.6, 20.0, 10.4, 36.8, 52.4
    ]
}

df = pd.DataFrame(data)

# CSV 저장
df.to_csv("adaptclip_visa_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_visa_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_visa_0shot.csv

# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 10,
    "Category": [
        "bagel", "cable_gland", "carrot", "cookie",
        "tire", "rope", "foam", "dowel",
        "peach", "potato"
    ],
    "I_AUROC": [
        93.4, 73.6, 78.7, 72.7,
        78.9, 76.8, 81.2, 74.0,
        86.5, 70.8
    ],
    "I_AUPR": [
        98.4, 92.4, 94.7, 92.0,
        93.7, 90.2, 95.0, 91.1,
        96.4, 90.0
    ],
    "I_F1max": [
        92.7, 90.2, 91.3, 88.0,
        87.4, 81.5, 89.9, 90.1,
        91.9, 89.8
    ],
    "P_AUROC": [
        99.6, 98.2, 98.1, 96.3,
        97.9, 96.9, 89.9, 96.6,
        99.1, 99.4
    ],
    "P_AUPR": [
        73.1, 30.1, 24.5, 42.9,
        29.7, 27.2, 23.7, 5.8,
        27.5, 29.9
    ],
    "P_F1max": [
        67.2, 33.6, 31.4, 44.2,
        36.7, 29.8, 32.4, 11.9,
        37.4, 36.8
    ]
}

df = pd.DataFrame(data)

# CSV 저장
df.to_csv("adaptclip_mad_sim_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_mad_sim_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_mad_sim_0shot.csv

# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 12,
    "Category": [
        "Woven_001", "Woven_127", "Woven_104",
        "Stratified_154", "Blotchy_099", "Woven_068",
        "Woven_125", "Marbled_078", "Perforated_037",
        "Mesh_114", "Fibrous_183", "Matted_069"
    ],
    "I_AUROC": [
        100.0, 94.8, 98.9,
        98.1, 98.3, 97.0,
        100.0, 99.1, 93.7,
        85.6, 98.8, 87.3
    ],
    "I_AUPR": [
        99.8, 95.4, 99.7,
        99.5, 99.4, 98.3,
        99.9, 99.7, 98.4,
        94.2, 99.6, 96.7
    ],
    "I_F1max": [
        100.0, 88.4, 98.1,
        96.4, 99.4, 93.0,
        100.0, 98.1, 93.9,
        84.7, 97.5, 91.2
    ],
    "P_AUROC": [
        99.8, 94.5, 95.2,
        99.6, 99.5, 98.7,
        99.5, 99.2, 93.5,
        93.7, 99.1, 99.5
    ],
    "P_AUPR": [
        78.2, 54.0, 67.6,
        77.6, 79.7, 55.8,
        73.9, 75.4, 62.3,
        58.0, 68.8, 73.6
    ],
    "P_F1max": [
        71.7, 54.6, 64.8,
        68.9, 69.4, 53.4,
        66.4, 67.5, 61.7,
        58.1, 60.7, 65.8
    ]
}

df = pd.DataFrame(data)

# CSV 저장
df.to_csv("adaptclip_btad_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_btad_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_btad_0shot.csv

# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 6,
    "Category": [
        "bracket_black",
        "bracket_brown",
        "bracket_white",
        "connector",
        "metal_plate",
        "tubes"
    ],
    "I_AUROC": [
        65.8,
        56.3,
        61.4,
        71.4,
        88.6,
        97.8
    ],
    "I_AUPR": [
        73.1,
        72.1,
        54.7,
        53.3,
        94.8,
        98.9
    ],
    "I_F1max": [
        77.9,
        80.3,
        71.4,
        61.9,
        91.8,
        94.8
    ],
    "P_AUROC": [
        96.4,
        92.6,
        99.5,
        96.1,
        93.3,
        97.8
    ],
    "P_AUPR": [
        15.8,
        2.9,
        4.0,
        14.4,
        60.4,
        54.6
    ],
    "P_F1max": [
        26.4,
        6.7,
        9.1,
        20.5,
        61.5,
        55.1
    ]
}

df = pd.DataFrame(data)

# CSV 저장
df.to_csv("adaptclip_mpdd_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_mpdd_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_mpdd_0shot.csv

# %%
import pandas as pd

data = {
    "Shot": ["0-shot"] * 30,
    "Category": [
        "audiojack", "bottle_cap", "button_battery", "end_cap",
        "eraser", "fire_hood", "mint", "mounts", "pcb",
        "phone_battery", "plastic_nut", "plastic_plug",
        "porcelain_doll", "regulator", "rolled_strip_base",
        "sim_card_set", "switch", "tape", "terminalblock",
        "toothbrush", "toy", "toy_brick", "transistor1",
        "u_block", "usb", "usb_adaptor", "vcpill",
        "wooden_beads", "woodstick", "zipper"
    ],
    "I_AUROC": [
        63.5, 66.2, 70.6, 66.1,
        86.4, 80.0, 66.4, 79.9, 61.9,
        82.1, 68.4, 69.5,
        77.9, 73.0, 87.1,
        89.4, 67.8, 93.0, 76.8,
        58.4, 63.3, 69.3, 71.3,
        77.2, 63.0, 72.8, 80.2,
        82.6, 75.6, 86.1
    ],
    "I_AUPR": [
        48.2, 63.1, 78.0, 70.9,
        85.8, 70.6, 65.7, 66.7, 73.0,
        81.1, 55.5, 57.6,
        60.7, 53.4, 93.5,
        92.9, 72.8, 91.4, 81.8,
        66.2, 71.4, 61.0, 75.5,
        64.9, 57.7, 62.2, 75.6,
        79.7, 55.9, 90.5
    ],
    "I_F1max": [
        53.4, 61.2, 73.4, 74.0,
        75.9, 64.8, 65.0, 67.5, 75.5,
        70.7, 54.7, 60.5,
        67.5, 53.7, 85.7,
        84.6, 70.5, 82.8, 71.5,
        69.9, 73.5, 61.6, 75.5,
        62.8, 65.0, 63.6, 67.7,
        73.1, 56.2, 86.2
    ],
    "P_AUROC": [
        94.9, 98.0, 98.2, 95.2,
        99.4, 99.0, 93.6, 97.9, 94.4,
        76.1, 96.1, 96.3,
        99.1, 92.1, 98.6,
        99.5, 84.6, 97.0, 96.8,
        91.1, 81.9, 97.6, 91.8,
        98.6, 93.2, 97.1, 98.0,
        98.4, 97.5, 95.5
    ],
    "P_AUPR": [
        11.3, 26.6, 50.8, 10.0,
        37.2, 37.1, 26.2, 39.0, 7.4,
        23.3, 33.3, 23.0,
        42.9, 16.2, 35.2,
        58.8, 11.8, 40.5, 36.5,
        11.1, 9.6, 22.7, 22.7,
        33.9, 5.1, 15.3, 48.4,
        41.9, 46.6, 22.3
    ],
    "P_F1max": [
        20.9, 36.8, 54.2, 18.2,
        45.6, 42.8, 38.6, 46.3, 13.5,
        34.5, 43.4, 33.4,
        44.9, 29.3, 40.8,
        59.6, 18.9, 50.0, 44.2,
        17.7, 17.8, 29.8, 32.3,
        43.1, 9.9, 25.3, 53.0,
        46.2, 52.2, 26.2
    ]
}

df = pd.DataFrame(data)

# CSV 저장
df.to_csv("adaptclip_mvtec_loco_0shot.csv", index=False)

print("CSV 저장 완료: adaptclip_mvtec_loco_0shot.csv")
# Out:
# CSV 저장 완료: adaptclip_mvtec_loco_0shot.csv
