# %% [markdown]
# # WinCLIP CodeReview
#
# ## Object
# 1. find anomaly patches
# 2. comparison normal/abnormal
# 3. create anomaly scores per patch
# 4. show result - heatmap, anomaly_score

# %% [markdown]
# ## forwad function
#
# - model을 설계할때 forward먼저 설게하는것이 도움이된다.
# - 처음에는, pseudo-code 먼저 작성후, 각각에 필요한 함수와 class를 정의.
# - 즉, 작은 부분부터 확장을 시켜야한다.
#
# ### image_encoder
# - winclip은 clip의 image_encoder를 사용한다.
# - image_encode 함수를 먼저 작성하자.

# %%
def forward(images):
    
    visual_features = encode_image(images)

    return

# %%
import open_clip
class WinCLIP:
    def __init__(self):
        self.model, self._, self.preprocess = open_clip.create_model_and_transforms(
            "ViT-B-16",
            pretrained = "laion2b_s34b_b88k"
        )
    def encode_image(self, image):
        self.preprocess(image)
